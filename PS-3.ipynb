# %% [markdown]
# # Question 3

# %%
# step1,2 and 3

from numpy import random
import numpy as np
import pandas as pd

a = random.choice([1,2,3,4], size=(100))
b = random.choice([1,2,3], size=(100))
c = np.random.randint(low=10000, high=30000, size=100)

dff = pd.DataFrame(data=zip(x,y,z),columns=['list_X','list_Y','list_Z'])
dff.head()
# Out:
#    list_X  list_Y  list_Z
# 0       4       3   26306
# 1       1       1   20249
# 2       1       1   20401
# 3       2       3   28872
# 4       3       2   16676

# %%
# step 4

dff.columns=['bedrs','bathrs','price_sqr_meter']
dff
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       4       3            26306
# 1       1       1            20249
# 2       1       1            20401
# 3       2       3            28872
# 4       3       2            16676
# ..    ...     ...              ...
# 95      4       2            29376
# 96      3       3            18101
# 97      2       2            25624
# 98      4       1            21262
# 99      4       2            23228
#
# [100 rows x 3 columns]

# %%
# step5

bigcolumn =dff.apply(lambda x:'%s_%s_%s' % (x['bedrs'],x['bathrs'],x['price_sqr_meter']),axis=1)
bigcolumn
# Out:
# 0     4_3_26306
# 1     1_1_20249
# 2     1_1_20401
# 3     2_3_28872
# 4     3_2_16676
#         ...
# 95    4_2_29376
# 96    3_3_18101
# 97    2_2_25624
# 98    4_1_21262
# 99    4_2_23228
# Length: 100, dtype: object

# %% [markdown]
# ### step 6
# ### yes, true

# %% [markdown]
# # Question 6

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


us_marriage_divorce_data = pd.read_csv('us-marriages-divorces-1867-2014.csv')
plt.figure(figsize=(10,6))
plt.title('Us marriage divorce data', fontdict={'fontweight':'bold', 'color': 'green','fontsize': 18})
plt.plot(us_marriage_divorce_data.Year, us_marriage_divorce_data.Marriages, 'b.-', label='Marriages')
plt.plot(us_marriage_divorce_data.Year, us_marriage_divorce_data.Divorces, 'r.-', label='Divorces')
plt.xlabel('Year')
plt.ylabel('Marriages\Divorces per capita')
plt.legend()
plt.savefig('Us marriage divorce data.png', dpi=350)
plt.show()

# %% [markdown]
# # Question 7

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

US_DivorceData= pd.read_csv('us-marriages-divorces-1867-2014.csv')
US_DivorceData= US_DivorceData [
    US_DivorceData ['Year'].apply(lambda x: x in [1900, 1950, 2000])]

years = tuple(US_DivorceData ['Year'].values.tolist())
marriages = tuple(US_DivorceData ['Marriages'].values.tolist())
divorces= tuple(US_DivorceData ['Divorces'].values.tolist())

# create plot
n_groups = 3

fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.45
opacity = 0.9

rects1 = plt.bar(index, marriages, bar_width,
alpha=opacity,
color='y',
label='Marriage')

rects2 = plt.bar(index + bar_width, divorces, bar_width,
alpha=opacity,
color='r',
label='Divorce')

plt.xlabel('Years')
plt.ylabel('Marriage\Divorce per capita')
plt.title('Us Marriage and Divorce data')
plt.xticks(index + bar_width, (1900, 1950, 2000))
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 8

# %%
import pandas as pd
import seaborn as sns

act = pd.read_csv('actor_kill_counts.csv')

ax1 = sns.barplot(x='Count', y='Actor', data=act, order=act.sort_values('Count', ascending=False).Actor)
ax1.set_xlabel('Kill Counts')
ax1.set_ylabel('Actor')
ax1.set_title("Deadliest actors in Hollywood", size=24)
# Out:
# Text(0.5, 1.0, 'Deadliest actors in Hollywood')

# %% [markdown]
# # Question 9

# %%
import pandas as pd
import matplotlib.pyplot as plt

rom = pd.read_csv('roman-emperor-reigns.csv')
rom_as= rom.loc[(rom['Cause_of_Death']=='Assassinated')]

rom_as

rom_as.groupby(['Emperor']).sum().plot(kind='pie', subplots=True,startangle=90,figsize=(18,14), autopct='%1.1f%%')
plt.title("Emperor's of Roman Empire 'Assassinated' \n with length of their region(relative)", fontsize=19)
# Out:
# Text(0.5, 1.0, "Emperor's of Roman Empire 'Assassinated' \n with length of their region(relative)")

# %% [markdown]
# # Question 10

# %%
Circle=pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')

Circle1= Circle.loc[(Circle['Year']>=2000)&(Circle['Year']<=2009)]

ss= sns.relplot(x="Total Arcade Revenue (billions)", y="Computer Science Doctorates Awarded (US)", hue="Year", size="Year",color="blue",
            sizes=(60, 500), alpha=.5, palette="muted",
            height=8, data=arc)
plt.title("Relationship between the total revenue earned by arcades\nAnd the number of Computer Science PhDs awarded in the U.S.\n 2000 - 2009", fontsize=24)
# Out:
# Text(0.5, 1, 'Relationship between the total revenue earned by arcades\nAnd the number of Computer Science PhDs awarded in the U.S.\n 2000 - 2009')
